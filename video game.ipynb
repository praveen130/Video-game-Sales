# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/praveen/video.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print(df.shape)
# Out:
# (16598, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df[df['Year'].isnull()]['Platform'].value_counts()
# Out:
# Wii     35
# PS2     34
# X360    30
# DS      30
# PS3     25
# XB      21
# 2600    17
# PC      17
# PSP     16
# GC      14
# GBA     11
# 3DS      9
# PS       7
# N64      3
# GB       1
# PSV      1
# Name: Platform, dtype: int64

# %%
order = df['Genre'].value_counts()
order.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.describe(exclude=np.number)
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %%
len(df['Year'].value_counts())
# Out:
# 39

# %%
df.pivot_table(index='Year',columns='Platform',values='Name',aggfunc='count')
# Out:
# Platform  2600  3DO    3DS    DC     DS    GB    GBA     GC   GEN   GG  ...  \
# Year                                                                    ...
# 1980.0     9.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1981.0    46.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1982.0    36.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1983.0    11.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1984.0     1.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1985.0     1.0  NaN    NaN   NaN    1.0   NaN    NaN    NaN   NaN  NaN  ...
# 1986.0     2.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1987.0     6.0  NaN    NaN   NaN    NaN   NaN    NaN    NaN   NaN  NaN  ...
# 1988.0     2.0  NaN    NaN   NaN    NaN   1.0    NaN    NaN   NaN  NaN  ...
# 1989.0     2.0  NaN    NaN   NaN    NaN  10.0    NaN    NaN   NaN  NaN  ...
# ...

# %%
df.groupby('Platform')['Year'].median().apply(lambda x: np.floor(x))
# Out:
# Platform
# 2600    1982.0
# 3DO     1995.0
# 3DS     2013.0
# DC      2000.0
# DS      2008.0
# GB      1997.0
# GBA     2003.0
# GC      2003.0
# GEN     1993.0
# GG      1992.0
# N64     1999.0
# NES     1986.0
# NG      1994.0
# PC      2009.0
# PCFX    1996.0
# PS      1998.0
# PS2     2005.0
# PS3     2011.0
# PS4     2015.0
# PSP     2009.0
# PSV     2014.0
# SAT     1996.0
# SCD     1994.0
# SNES    1994.0
# TG16    1995.0
# WS      2000.0
# Wii     2009.0
# WiiU    2013.0
# X360    2010.0
# XB      2004.0
# XOne    2015.0
# Name: Year, dtype: float64

# %%
df.groupby('Platform')['Year'].transform('median').apply(lambda x: np.floor(x))
# Out:
# 0        2009.0
# 1        1986.0
# 2        2009.0
# 3        2009.0
# 4        1997.0
#           ...
# 16593    2003.0
# 16594    2003.0
# 16595    2005.0
# 16596    2008.0
# 16597    2003.0
# Name: Year, Length: 16598, dtype: float64

# %%
df.iloc[0]
# Out:
# Rank                     1
# Name            Wii Sports
# Platform               Wii
# Year                  2006
# Genre               Sports
# Publisher         Nintendo
# NA_Sales             41.49
# EU_Sales             29.02
# JP_Sales              3.77
# Other_Sales           8.46
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
df['Publisher'].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Simon & Schuster Interactive       1
# On Demand                          1
# Bohemia Interactive                1
# Magical Company                    1
# Technos Japan Corporation          1
# Name: Publisher, Length: 578, dtype: int64

# %%
df[df['Publisher'].isnull()]
# Out:
#         Rank                                               Name Platform  \
# 470      471                         wwe Smackdown vs. Raw 2006      PS2
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(df['Genre'])
plt.show()
# Out:
# /home/praveen/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.pivot_table(index='Genre',values='Global_Sales',aggfunc='sum').plot(kind='bar',figsize=(12,7),rot=0)
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.groupby('Year')['Name'].count().plot(figsize=(12,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
top_sale_reg = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']]

# summing up the entire sales data as per region
top_sale_reg = top_sale_reg.sum().reset_index()

# renaming the columns to make it more intuitive
top_sale_reg = top_sale_reg.rename(columns={"index": "region", 0: "sale"})

top_sale_reg.head()
# Out:
#         region     sale
# 0     NA_Sales  4392.95
# 1     EU_Sales  2434.13
# 2     JP_Sales  1291.02
# 3  Other_Sales   797.75

# %%
labels = top_sale_reg['region']
sizes = top_sale_reg['sale']

plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)

plt.show()

# %%
# data is already sorted according to global sales
top_game_sale = df.head(20)

top_game_sale = top_game_sale[['Name', 'Year', 'Genre', 'Global_Sales']]

top_game_sale = top_game_sale.sort_values(by=['Global_Sales'], ascending=False)
# top_game_sale

# %%
name = top_game_sale['Name']
year = top_game_sale['Year']
y = np.arange(0, 20)

# %%
plt.figure(figsize=(30, 18))
g = sns.barplot(x='Name', y='Global_Sales', data=top_game_sale)
index = 0
for value in top_game_sale['Global_Sales']:
    g.text(index, value, name[index], color='#000', size=14, rotation= 90, ha="center")
    index += 1

plt.xticks(y, top_game_sale['Year'], fontsize=14, rotation=90)
plt.xlabel('Release Year')
plt.show()

# %%
year_sale_dx = df.groupby(by=['Year', 'Genre'])['Global_Sales'].sum().reset_index()

# Comparing with only the highest sales figure to get a binary value of true or false
year_sale = year_sale_dx.groupby(by=['Year'])['Global_Sales'].transform(max) == year_sale_dx['Global_Sales']

# Subsetting to keep only the highest value each year in the datframe
year_sale_max = year_sale_dx[year_sale].reset_index(drop=True)

genre = year_sale_max['Genre']

# %%
plt.figure(figsize=(30, 18))
g = sns.barplot(x='Year', y='Global_Sales', data=year_sale_max)

# Adding values at the top of each bar
index = 0
for value in year_sale_max['Global_Sales']:
    g.text(index, value + 1, str(genre[index] + '----' +str(round(value, 2))), color='#000', size=14, rotation= 90, ha="center")
    
    index += 1

plt.xticks(rotation=90)
plt.show()

# %%
validation = pd.DataFrame(df.groupby(['Name','Platform','Year'])['Name'].count())
validation[validation['Name']>1]
# Out:
#                                Name
# Name          Platform Year
# Madden NFL 13 PS3      2012.0     2

# %%
df.drop_duplicates(subset=['Name','Platform','Year'],inplace = True)

# %%
validation = pd.DataFrame(df.groupby(['Name','Platform','Year'])['Name'].count())
validation[validation['Name']>1]
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
sale_name=df.pivot_table(index='Name',aggfunc='sum',values=['NA_Sales',
       'EU_Sales', 'JP_Sales', 'Other_Sales','Global_Sales'])

# %%
sale_name.sort_values('Global_Sales',ascending=False)
# Out:
#                                     EU_Sales  Global_Sales  JP_Sales  \
# Name
# Wii Sports                             29.02         82.74      3.77
# Grand Theft Auto V                     23.04         55.92      1.39
# Super Mario Bros.                       4.88         45.31      6.96
# Tetris                                  2.95         35.84      6.03
# Mario Kart Wii                         12.88         35.82      3.79
# ...                                      ...           ...       ...
# Grand Prix Legends                      0.01          0.01      0.00
# Paranormal Pursuit: The Gifted One      0.01          0.01      0.00
# Mamoru-kun wa Norowarete Shimatta!      0.00          0.01      0.01
# Homeworld Remastered Collection         0.01          0.01      0.00
# Fab 5 Soccer                            0.00          0.01      0.00
#
#                                     NA_Sales  Other_Sales
# Name
# Wii Sports                             41.49         8.46
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(sale_name.corr(),annot=True)
plt.title('correlation',fontsize=21,color='navy')
plt.show()
